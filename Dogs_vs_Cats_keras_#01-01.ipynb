# %% [markdown]
# <a href="https://colab.research.google.com/github/koalalovepabro/Kaggle-Study/blob/main/Dogs_vs_Cats_keras_%2301-01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글드라이브 서버연결
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("/content/gdrive/MyDrive/datasets/.kaggle"))
# Out:
# ['test1', 'kaggle.json', 'train.zip', 'sampleSubmission.csv', 'test1.zip', 'train', 'Dogs vs Cats.ipynb']

# %% [markdown]
# # Define Constants

# %%
FAST_RUN = False     # 아래에 사용..?
IMAGE_WIDTH = 128    # 이미지 넓이 (가로)
IMAGE_HEIGHT = 128   # 이미지 높이 (세로)
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3   # 이미지 depth (RGB)

# %% [markdown]
# # Prepare Training Data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# os.listdir : 디렉터리 내에 있는 모든 파일 및 디렉터리 리스트를 가져와서 indexing
filenames = os.listdir("/content/gdrive/MyDrive/datasets/.kaggle/train")

# 빈 list를 한개 만든다
categories = []

# filenames에 있는 list들을 한개씩 받아온다.
for filename in filenames:
  # .으로 split하고 0번째에 있는 것을 category 변수에 저장 ( dog 또는 cat으로 저장될 것 )
  category = filename.split('.')[0]
  if category == 'dog':
    categories.append(1)  # 강아지면, categories 리스트에 1을 추가 ( OHE 효과 )
  else:
    categories.append(0)  # 강아지가 아니면 (고양이면), categories 리스트에 0을 추가 ( OHE 효과 )

# 데이터 프레임 만들기 - filename col에 filenames value 넣고, category col에 categories value 넣기
df = pd.DataFrame({
    'filename' : filenames,
    'category' : categories 
})

# %%
filenames
# Out:
# ['cat.9076.jpg',
#  'cat.9114.jpg',
#  'cat.9082.jpg',
#  'cat.909.jpg',
#  'cat.9088.jpg',
#  'cat.9078.jpg',
#  'cat.9079.jpg',
#  'cat.9100.jpg',
#  'cat.91.jpg',
#  'cat.9104.jpg',
#  'cat.9095.jpg',
#  'cat.9122.jpg',
#  'cat.9119.jpg',
#  'cat.9101.jpg',
#  'cat.9071.jpg',
#  'cat.9085.jpg',
#  'cat.9116.jpg',
#  'cat.9108.jpg',
#  'cat.9115.jpg',
#  'cat.9094.jpg',
#  'cat.9105.jpg',
#  'cat.9070.jpg',
#  'cat.9077.jpg',
#  'cat.9090.jpg',
#  'cat.9091.jpg',
#  'cat.9066.jpg',
#  'cat.9107.jpg',
#  'cat.9117.jpg',
#  'cat.9073.jpg',
#  'cat.9132.jpg',
#  'cat.9176.jpg',
#  'cat.9130.jpg',
#  'cat.9134.jpg',
#  'cat.9151.jpg',
#  'cat.9139.jpg',
#  'cat.9160.jpg',
#  'cat.9147.jpg',
#  'cat.916.jpg',
#  'cat.9126.jpg',
#  'cat.9129.jpg',
#  'cat.9174.jpg',
#  'cat.9149.jpg',
#  'cat.9128.jpg',
#  'cat.9135.jpg',
#  'cat.9172.jpg',
#  'cat.9141.jpg',
#  'cat.9140.jpg',
#  'cat.9142.jpg',
#  'cat.913.jpg',
#  'cat.9177.jpg',
#  'cat.9155.jpg',
#  'cat.914.jpg',
#  'cat.9179.jpg',
#  'cat.9148.jpg',
#  'cat.9169.jpg',
#  'cat.9164.jpg',
#  'cat.9157.jpg',
#  'cat.9175.jpg',
#  'cat.9154.jpg',
#  'cat.9125.jpg',
#  'cat.9167.jpg',
#  'cat.9173.jpg',
#  'cat.9156.jpg',
#  'cat.9161.jpg',
#  'cat.915.jpg',
#  'cat.9144.jpg',
#  'cat.9127.jpg',
#  'cat.9168.jpg',
#  'cat.9166.jpg',
#  'cat.9137.jpg',
#  'cat.9158.jpg',
#  'cat.9145.jpg',
#  'cat.9162.jpg',
#  'cat.9136.jpg',
#  'cat.9131.jpg',
#  'cat.9163.jpg',
#  'cat.9178.jpg',
#  'cat.9159.jpg',
#  'cat.9133.jpg',
#  'cat.9153.jpg',
#  'cat.9152.jpg',
#  'cat.9170.jpg',
#  'cat.9165.jpg',
#  'cat.9124.jpg',
#  'cat.9146.jpg',
#  'cat.9143.jpg',
#  'cat.917.jpg',
#  'cat.9171.jpg',
#  'cat.9138.jpg',
#  'cat.9150.jpg',
#  'cat.9232.jpg',
#  'cat.9206.jpg',
#  'cat.9199.jpg',
#  'cat.9200.jpg',
#  'cat.9216.jpg',
#  'cat.9185.jpg',
#  'cat.9183.jpg',
#  'cat.9204.jpg',
#  'cat.9212.jpg',
#  'cat.9210.jpg',
#  'cat.9187.jpg',
#  'cat.9193.jpg',
#  'cat.9207.jpg',
#  'cat.9191.jpg',
#  'cat.9233.jpg',
#  'cat.92.jpg',
#  'cat.9229.jpg',
#  'cat.9203.jpg',
#  'cat.9205.jpg',
#  'cat.9230.jpg',
#  'cat.9192.jpg',
#  'cat.9217.jpg',
#  'cat.9228.jpg',
#  'cat.9182.jpg',
#  'cat.9198.jpg',
#  'cat.9208.jpg',
#  'cat.9222.jpg',
#  'cat.9231.jpg',
#  'cat.9180.jpg',
#  'cat.9186.jpg',
#  'cat.921.jpg',
#  'cat.9201.jpg',
#  'cat.9223.jpg',
#  'cat.9235.jpg',
#  'cat.9213.jpg',
#  'cat.9219.jpg',
#  'cat.9234.jpg',
#  'cat.922.jpg',
#  'cat.9209.jpg',
#  'cat.920.jpg',
#  'cat.9188.jpg',
#  'cat.9214.jpg',
#  'cat.9184.jpg',
#  'cat.9189.jpg',
#  'cat.9215.jpg',
#  'cat.919.jpg',
#  'cat.9221.jpg',
#  'cat.9196.jpg',
#  'cat.9224.jpg',
#  'cat.918.jpg',
#  'cat.9190.jpg',
#  'cat.9227.jpg',
#  'cat.9226.jpg',
#  'cat.9218.jpg',
#  'cat.9194.jpg',
#  'cat.923.jpg',
#  'cat.9225.jpg',
#  'cat.9202.jpg',
#  'cat.9211.jpg',
#  'cat.9181.jpg',
#  'cat.9220.jpg',
#  'cat.9197.jpg',
#  'cat.9195.jpg',
#  'cat.9251.jpg',
#  'cat.9249.jpg',
#  'cat.9283.jpg',
#  'cat.9246.jpg',
#  'cat.9291.jpg',
#  'cat.926.jpg',
#  'cat.9289.jpg',
#  'cat.9254.jpg',
#  'cat.9271.jpg',
#  'cat.9297.jpg',
#  'cat.9241.jpg',
#  'cat.9239.jpg',
#  'cat.928.jpg',
#  'cat.9274.jpg',
#  'cat.9265.jpg',
#  'cat.9257.jpg',
#  'cat.9281.jpg',
#  'cat.9245.jpg',
#  'cat.929.jpg',
#  'cat.924.jpg',
#  'cat.9261.jpg',
#  'cat.9252.jpg',
#  'cat.9278.jpg',
#  'cat.9275.jpg',
#  'cat.9253.jpg',
#  'cat.925.jpg',
#  'cat.9280.jpg',
#  'cat.9248.jpg',
#  'cat.9260.jpg',
#  'cat.9269.jpg',
#  'cat.9263.jpg',
#  'cat.9287.jpg',
#  'cat.9255.jpg',
#  'cat.9272.jpg',
#  'cat.9268.jpg',
#  'cat.9266.jpg',
#  'cat.9296.jpg',
#  'cat.9267.jpg',
#  'cat.9270.jpg',
#  'cat.9276.jpg',
#  'cat.9262.jpg',
#  'cat.9273.jpg',
#  'cat.9247.jpg',
#  'cat.9237.jpg',
#  'cat.9236.jpg',
#  'cat.9282.jpg',
#  'cat.9277.jpg',
#  'cat.9240.jpg',
#  'cat.9244.jpg',
#  'cat.9285.jpg',
#  'cat.9294.jpg',
#  'cat.927.jpg',
#  'cat.9293.jpg',
#  'cat.9279.jpg',
#  'cat.9259.jpg',
#  'cat.9295.jpg',
#  'cat.9292.jpg',
#  'cat.9290.jpg',
#  'cat.9256.jpg',
#  'cat.9258.jpg',
#  'cat.9242.jpg',
#  'cat.9243.jpg',
#  'cat.9284.jpg',
#  'cat.9238.jpg',
#  'cat.9250.jpg',
#  'cat.9288.jpg',
#  'cat.9286.jpg',
#  'cat.9264.jpg',
#  'cat.9322.jpg',
#  'cat.9298.jpg',
#  'cat.9343.jpg',
#  'cat.9318.jpg',
#  'cat.9328.jpg',
#  'cat.9333.jpg',
#  'cat.9351.jpg',
#  'cat.9304.jpg',
#  'cat.9344.jpg',
#  'cat.9329.jpg',
#  'cat.933.jpg',
#  'cat.9313.jpg',
#  'cat.9302.jpg',
#  'cat.9299.jpg',
#  'cat.9350.jpg',
#  'cat.9324.jpg',
#  'cat.9353.jpg',
#  'cat.9309.jpg',
#  'cat.9332.jpg',
#  'cat.9312.jpg',
#  'cat.93.jpg',
#  'cat.9325.jpg',
#  'cat.9327.jpg',
#  'cat.9311.jpg',
#  'cat.9300.jpg',
#  'cat.9335.jpg',
#  'cat.9314.jpg',
#  'cat.9334.jpg',
#  'cat.9303.jpg',
#  'cat.9301.jpg',
#  'cat.9330.jpg',
#  'cat.9339.jpg',
#  'cat.9308.jpg',
#  'cat.9352.jpg',
#  'cat.9348.jpg',
#  'cat.9305.jpg',
#  'cat.9317.jpg',
#  'cat.9346.jpg',
#  'cat.9326.jpg',
#  'cat.9336.jpg',
#  'cat.9320.jpg',
#  'cat.9306.jpg',
#  'cat.9337.jpg',
#  'cat.9349.jpg',
#  'cat.9341.jpg',
#  'cat.932.jpg',
#  'cat.935.jpg',
#  'cat.9321.jpg',
#  'cat.9310.jpg',
#  'cat.9307.jpg',
#  'cat.9316.jpg',
#  'cat.9338.jpg',
#  'cat.9340.jpg',
#  'cat.9342.jpg',
#  'cat.9323.jpg',
#  'cat.9331.jpg',
#  'cat.931.jpg',
#  'cat.9315.jpg',
#  'cat.9319.jpg',
#  'cat.934.jpg',
#  'cat.9345.jpg',
#  'cat.930.jpg',
#  'cat.9347.jpg',
#  'cat.9373.jpg',
#  'cat.9364.jpg',
#  'cat.9390.jpg',
#  'cat.9371.jpg',
#  'cat.9414.jpg',
#  'cat.9397.jpg',
#  'cat.9366.jpg',
#  'cat.9379.jpg',
#  'cat.9369.jpg',
#  'cat.9365.jpg',
#  'cat.9404.jpg',
#  'cat.9395.jpg',
#  'cat.9384.jpg',
#  'cat.9406.jpg',
#  'cat.9375.jpg',
#  'cat.9391.jpg',
#  'cat.9415.jpg',
#  'cat.941.jpg',
#  'cat.9360.jpg',
#  'cat.9400.jpg',
#  'cat.9355.jpg',
#  'cat.9359.jpg',
#  'cat.9387.jpg',
#  'cat.9374.jpg',
#  'cat.9370.jpg',
#  'cat.9358.jpg',
#  'cat.938.jpg',
#  'cat.9363.jpg',
#  'cat.9394.jpg',
#  'cat.9372.jpg',
#  'cat.9412.jpg',
#  'cat.9407.jpg',
#  'cat.9362.jpg',
#  'cat.9386.jpg',
#  'cat.939.jpg',
#  'cat.9354.jpg',
#  'cat.9408.jpg',
#  'cat.9382.jpg',
#  'cat.9401.jpg',
#  'cat.9396.jpg',
#  'cat.9388.jpg',
#  'cat.9403.jpg',
#  'cat.94.jpg',
#  'cat.9385.jpg',
#  'cat.9416.jpg',
#  'cat.9399.jpg',
#  'cat.9402.jpg',
#  'cat.940.jpg',
#  'cat.9367.jpg',
#  'cat.9380.jpg',
#  'cat.9383.jpg',
#  'cat.9357.jpg',
#  'cat.9377.jpg',
#  'cat.9405.jpg',
#  'cat.9392.jpg',
#  'cat.9378.jpg',
#  'cat.9410.jpg',
#  'cat.9411.jpg',
#  'cat.9409.jpg',
#  'cat.9356.jpg',
#  'cat.9376.jpg',
#  'cat.9393.jpg',
#  'cat.9398.jpg',
#  'cat.937.jpg',
#  'cat.9361.jpg',
#  'cat.9413.jpg',
#  'cat.936.jpg',
#  'cat.9368.jpg',
#  'cat.9381.jpg',
#  'cat.9389.jpg',
#  'cat.9429.jpg',
#  'cat.9472.jpg',
#  'cat.9439.jpg',
#  'cat.9423.jpg',
#  'cat.9474.jpg',
#  'cat.9437.jpg',
#  'cat.942.jpg',
#  'cat.9427.jpg',
#  'cat.9440.jpg',
#  'cat.945.jpg',
#  'cat.9451.jpg',
#  'cat.9421.jpg',
#  'cat.9464.jpg',
#  'cat.947.jpg',
#  'cat.9477.jpg',
#  'cat.9442.jpg',
#  'cat.9419.jpg',
#  'cat.9462.jpg',
#  'cat.9444.jpg',
#  'cat.9433.jpg',
#  'cat.9470.jpg',
#  'cat.9446.jpg',
#  'cat.9443.jpg',
#  'cat.943.jpg',
#  'cat.9432.jpg',
#  'cat.9466.jpg',
#  'cat.9478.jpg',
#  'cat.9456.jpg',
#  'cat.9476.jpg',
#  'cat.9447.jpg',
#  'cat.944.jpg',
#  'cat.9459.jpg',
#  'cat.9469.jpg',
#  'cat.9436.jpg',
#  'cat.9420.jpg',
#  'cat.9467.jpg',
#  'cat.9445.jpg',
#  'cat.9458.jpg',
#  'cat.9465.jpg',
#  'cat.9454.jpg',
#  'cat.946.jpg',
#  'cat.9461.jpg',
#  'cat.9455.jpg',
#  'cat.9450.jpg',
#  'cat.9424.jpg',
#  'cat.9463.jpg',
#  'cat.9448.jpg',
#  'cat.9435.jpg',
#  'cat.9471.jpg',
#  'cat.9473.jpg',
#  'cat.9438.jpg',
#  'cat.9430.jpg',
#  'cat.9457.jpg',
#  'cat.9441.jpg',
#  'cat.9428.jpg',
#  'cat.9417.jpg',
#  'cat.9434.jpg',
#  'cat.9426.jpg',
#  'cat.9460.jpg',
#  'cat.9453.jpg',
#  'cat.9425.jpg',
#  'cat.9468.jpg',
#  'cat.9449.jpg',
#  'cat.9475.jpg',
#  'cat.9452.jpg',
#  'cat.9431.jpg',
#  'cat.9422.jpg',
#  'cat.9418.jpg',
#  'cat.9486.jpg',
#  'cat.9502.jpg',
#  'cat.9513.jpg',
#  'cat.9511.jpg',
#  'cat.9481.jpg',
#  'cat.951.jpg',
#  'cat.9516.jpg',
#  'cat.9487.jpg',
#  'cat.9495.jpg',
#  'cat.9536.jpg',
#  'cat.9530.jpg',
#  'cat.953.jpg',
#  'cat.9534.jpg',
#  'cat.9503.jpg',
#  'cat.9514.jpg',
#  'cat.9499.jpg',
#  'cat.9538.jpg',
#  'cat.9521.jpg',
#  'cat.9483.jpg',
#  'cat.9488.jpg',
#  'cat.9480.jpg',
#  'cat.9527.jpg',
#  'cat.9494.jpg',
#  'cat.9537.jpg',
#  'cat.9507.jpg',
#  'cat.9510.jpg',
#  'cat.9526.jpg',
#  'cat.9493.jpg',
#  'cat.95.jpg',
#  'cat.9528.jpg',
#  'cat.9500.jpg',
#  'cat.9485.jpg',
#  'cat.9515.jpg',
#  'cat.949.jpg',
#  'cat.9512.jpg',
#  'cat.9504.jpg',
#  'cat.9479.jpg',
#  'cat.9535.jpg',
#  'cat.9518.jpg',
#  'cat.9491.jpg',
#  'cat.9501.jpg',
#  'cat.9522.jpg',
#  'cat.950.jpg',
#  'cat.9524.jpg',
#  'cat.9531.jpg',
#  'cat.9505.jpg',
#  'cat.9492.jpg',
#  'cat.9520.jpg',
#  'cat.9484.jpg',
#  'cat.9508.jpg',
#  'cat.9482.jpg',
#  'cat.9525.jpg',
#  'cat.9523.jpg',
#  'cat.9533.jpg',
#  'cat.9497.jpg',
#  'cat.952.jpg',
#  'cat.9489.jpg',
#  'cat.9498.jpg',
#  'cat.9532.jpg',
#  'cat.9496.jpg',
#  'cat.948.jpg',
#  'cat.9509.jpg',
#  'cat.9529.jpg',
#  'cat.9490.jpg',
#  'cat.9519.jpg',
#  'cat.9517.jpg',
#  'cat.9506.jpg',
#  'cat.9593.jpg',
#  'cat.9565.jpg',
#  'cat.9576.jpg',
#  'cat.9541.jpg',
#  'cat.9540.jpg',
#  'cat.9549.jpg',
#  'cat.9573.jpg',
#  'cat.9539.jpg',
#  'cat.9596.jpg',
#  'cat.9581.jpg',
#  'cat.9584.jpg',
#  'cat.9550.jpg',
#  'cat.9544.jpg',
#  'cat.9543.jpg',
#  'cat.956.jpg',
#  'cat.9592.jpg',
#  'cat.9562.jpg',
#  'cat.9547.jpg',
#  'cat.958.jpg',
#  'cat.9577.jpg',
#  'cat.959.jpg',
#  'cat.9563.jpg',
#  'cat.9594.jpg',
#  'cat.9579.jpg',
#  'cat.9545.jpg',
#  'cat.955.jpg',
#  'cat.9555.jpg',
#  'cat.9598.jpg',
#  'cat.9553.jpg',
#  'cat.9554.jpg',
#  'cat.9567.jpg',
#  'cat.9557.jpg',
#  'cat.9559.jpg',
#  'cat.9558.jpg',
#  'cat.9561.jpg',
#  'cat.9560.jpg',
#  'cat.9556.jpg',
#  'cat.9568.jpg',
#  'cat.9588.jpg',
#  'cat.9591.jpg',
#  'cat.9595.jpg',
#  'cat.9569.jpg',
#  'cat.957.jpg',
#  'cat.9583.jpg',
#  'cat.9575.jpg',
#  'cat.9570.jpg',
#  'cat.9582.jpg',
#  'cat.9590.jpg',
#  'cat.9551.jpg',
#  'cat.9552.jpg',
#  'cat.9566.jpg',
#  'cat.9571.jpg',
#  'cat.9580.jpg',
#  'cat.9597.jpg',
#  'cat.9548.jpg',
#  'cat.9587.jpg',
#  'cat.954.jpg',
#  'cat.9585.jpg',
#  'cat.9564.jpg',
#  'cat.9578.jpg',
#  'cat.9542.jpg',
#  'cat.9546.jpg',
#  'cat.9574.jpg',
#  'cat.9572.jpg',
#  'cat.9586.jpg',
#  'cat.9589.jpg',
#  'cat.9620.jpg',
#  'cat.9611.jpg',
#  'cat.9633.jpg',
#  'cat.960.jpg',
#  'cat.9646.jpg',
#  'cat.9641.jpg',
#  'cat.9613.jpg',
#  'cat.9626.jpg',
#  'cat.962.jpg',
#  'cat.9654.jpg',
#  'cat.9647.jpg',
#  'cat.9604.jpg',
#  'cat.9616.jpg',
#  'cat.9639.jpg',
#  'cat.9642.jpg',
#  'cat.9640.jpg',
#  'cat.9627.jpg',
#  'cat.9601.jpg',
#  'cat.9636.jpg',
#  'cat.9610.jpg',
#  'cat.9599.jpg',
#  'cat.9629.jpg',
#  'cat.9618.jpg',
#  'cat.9638.jpg',
#  'cat.9653.jpg',
#  'cat.9605.jpg',
#  'cat.9645.jpg',
#  'cat.9632.jpg',
#  'cat.9648.jpg',
#  'cat.9650.jpg',
#  'cat.9644.jpg',
#  'cat.9615.jpg',
#  'cat.9609.jpg',
#  'cat.96.jpg',
#  'cat.9600.jpg',
#  'cat.9651.jpg',
#  'cat.964.jpg',
#  'cat.9643.jpg',
#  'cat.9607.jpg',
#  'cat.9619.jpg',
#  'cat.9631.jpg',
#  'cat.9621.jpg',
#  'cat.9612.jpg',
#  'cat.963.jpg',
#  'cat.9623.jpg',
#  'cat.9606.jpg',
#  'cat.9628.jpg',
#  'cat.9649.jpg',
#  'cat.9614.jpg',
#  'cat.965.jpg',
#  'cat.9608.jpg',
#  'cat.9655.jpg',
#  'cat.9617.jpg',
#  'cat.9602.jpg',
#  'cat.9624.jpg',
#  'cat.9603.jpg',
#  'cat.9622.jpg',
#  'cat.9630.jpg',
#  'cat.9625.jpg',
#  'cat.9635.jpg',
#  'cat.961.jpg',
#  'cat.9634.jpg',
#  'cat.9637.jpg',
#  'cat.9652.jpg',
#  'cat.9677.jpg',
#  'cat.9681.jpg',
#  'cat.9657.jpg',
#  'cat.9661.jpg',
#  'cat.9674.jpg',
#  'cat.97.jpg',
#  'cat.9680.jpg',
#  'cat.9700.jpg',
#  'cat.9678.jpg',
#  'cat.9696.jpg',
#  'cat.9686.jpg',
#  'cat.9691.jpg',
#  'cat.9702.jpg',
#  'cat.9665.jpg',
#  'cat.9707.jpg',
#  'cat.9659.jpg',
#  'cat.9671.jpg',
#  'cat.9698.jpg',
#  'cat.9672.jpg',
#  'cat.9663.jpg',
#  'cat.969.jpg',
#  'cat.9666.jpg',
#  'cat.968.jpg',
#  'cat.9701.jpg',
#  'cat.9704.jpg',
#  'cat.9685.jpg',
#  'cat.9706.jpg',
#  'cat.9699.jpg',
#  'cat.9705.jpg',
#  'cat.966.jpg',
#  'cat.9667.jpg',
#  'cat.9660.jpg',
#  'cat.9683.jpg',
#  'cat.9662.jpg',
#  'cat.9694.jpg',
#  'cat.9692.jpg',
#  'cat.9693.jpg',
#  'cat.9668.jpg',
#  'cat.9689.jpg',
#  'cat.9676.jpg',
#  'cat.9679.jpg',
#  'cat.9684.jpg',
#  'cat.9682.jpg',
#  'cat.9669.jpg',
#  'cat.9703.jpg',
#  'cat.9690.jpg',
#  'cat.9688.jpg',
#  'cat.9658.jpg',
#  'cat.970.jpg',
#  'cat.9675.jpg',
#  'cat.9670.jpg',
#  'cat.9687.jpg',
#  'cat.9656.jpg',
#  'cat.9695.jpg',
#  'cat.9673.jpg',
#  'cat.9697.jpg',
#  'cat.967.jpg',
#  'cat.9664.jpg',
#  'cat.9742.jpg',
#  'cat.9765.jpg',
#  'cat.9750.jpg',
#  'cat.9739.jpg',
#  'cat.9760.jpg',
#  'cat.9754.jpg',
#  'cat.9713.jpg',
#  'cat.973.jpg',
#  'cat.9744.jpg',
#  'cat.9724.jpg',
#  'cat.9759.jpg',
#  'cat.9727.jpg',
#  'cat.9728.jpg',
#  'cat.9746.jpg',
#  'cat.9758.jpg',
#  'cat.9741.jpg',
#  'cat.9762.jpg',
#  'cat.9718.jpg',
#  'cat.976.jpg',
#  'cat.9737.jpg',
#  'cat.9725.jpg',
#  'cat.9733.jpg',
#  'cat.9721.jpg',
#  'cat.9714.jpg',
#  'cat.9715.jpg',
#  'cat.9726.jpg',
#  'cat.9717.jpg',
#  'cat.9738.jpg',
#  'cat.9712.jpg',
#  'cat.9755.jpg',
#  'cat.9716.jpg',
#  'cat.9748.jpg',
#  'cat.9736.jpg',
#  'cat.9745.jpg',
#  'cat.9757.jpg',
#  'cat.9740.jpg',
#  'cat.9756.jpg',
#  'cat.9752.jpg',
#  'cat.9743.jpg',
#  'cat.975.jpg',
#  'cat.9711.jpg',
#  'cat.9753.jpg',
#  'cat.971.jpg',
#  'cat.9730.jpg',
#  'cat.9720.jpg',
#  'cat.9731.jpg',
#  'cat.9763.jpg',
#  'cat.9761.jpg',
#  'cat.9751.jpg',
#  'cat.9719.jpg',
#  'cat.9710.jpg',
#  'cat.9732.jpg',
#  'cat.974.jpg',
#  'cat.9729.jpg',
#  'cat.9709.jpg',
#  'cat.9723.jpg',
#  'cat.9747.jpg',
#  'cat.9722.jpg',
#  'cat.9764.jpg',
#  'cat.9734.jpg',
#  'cat.9708.jpg',
#  'cat.972.jpg',
#  'cat.9735.jpg',
#  'cat.9749.jpg',
#  'cat.9797.jpg',
#  'cat.9790.jpg',
#  'cat.9799.jpg',
#  'cat.9801.jpg',
#  'cat.982.jpg',
#  'cat.9780.jpg',
#  'cat.9773.jpg',
#  'cat.9777.jpg',
#  'cat.9808.jpg',
#  'cat.9807.jpg',
#  'cat.9818.jpg',
#  'cat.9800.jpg',
#  'cat.9813.jpg',
#  'cat.9795.jpg',
#  'cat.9766.jpg',
#  'cat.9809.jpg',
#  'cat.9805.jpg',
#  'cat.98.jpg',
#  'cat.9774.jpg',
#  'cat.9791.jpg',
#  'cat.9820.jpg',
#  'cat.9782.jpg',
#  'cat.9810.jpg',
#  'cat.9796.jpg',
#  'cat.9792.jpg',
#  'cat.9793.jpg',
#  'cat.981.jpg',
#  'cat.9775.jpg',
#  'cat.9770.jpg',
#  'cat.9803.jpg',
#  'cat.9817.jpg',
#  'cat.9789.jpg',
#  'cat.9798.jpg',
#  'cat.9778.jpg',
#  'cat.9771.jpg',
#  'cat.9787.jpg',
#  'cat.9811.jpg',
#  'cat.9781.jpg',
#  'cat.9804.jpg',
#  'cat.977.jpg',
#  'cat.9783.jpg',
#  'cat.9806.jpg',
#  'cat.9815.jpg',
#  'cat.9767.jpg',
#  'cat.9794.jpg',
#  'cat.9785.jpg',
#  'cat.9784.jpg',
#  'cat.9779.jpg',
#  'cat.9802.jpg',
#  'cat.9812.jpg',
#  'cat.979.jpg',
#  'cat.9816.jpg',
#  'cat.978.jpg',
#  'cat.9786.jpg',
#  'cat.9788.jpg',
#  'cat.980.jpg',
#  'cat.9768.jpg',
#  'cat.9769.jpg',
#  'cat.9814.jpg',
#  'cat.9776.jpg',
#  'cat.9772.jpg',
#  'cat.9819.jpg',
#  'cat.9876.jpg',
#  'cat.9856.jpg',
#  'cat.9852.jpg',
#  'cat.9843.jpg',
#  'cat.9867.jpg',
#  'cat.9858.jpg',
#  'cat.9878.jpg',
#  'cat.9875.jpg',
#  'cat.9869.jpg',
#  'cat.9861.jpg',
#  'cat.9871.jpg',
#  'cat.9829.jpg',
#  'cat.9850.jpg',
#  'cat.9862.jpg',
#  'cat.9880.jpg',
#  'cat.9865.jpg',
#  'cat.9835.jpg',
#  'cat.9854.jpg',
#  'cat.9863.jpg',
#  'cat.9864.jpg',
#  'cat.9846.jpg',
#  'cat.9832.jpg',
#  'cat.9855.jpg',
#  'cat.9881.jpg',
#  'cat.9853.jpg',
#  'cat.9844.jpg',
#  'cat.9866.jpg',
#  'cat.9827.jpg',
#  'cat.9877.jpg',
#  'cat.9841.jpg',
#  'cat.984.jpg',
#  'cat.9868.jpg',
#  'cat.9842.jpg',
#  'cat.9870.jpg',
#  'cat.9840.jpg',
#  'cat.9834.jpg',
#  'cat.9851.jpg',
#  'cat.9833.jpg',
#  'cat.983.jpg',
#  'cat.9847.jpg',
#  'cat.9873.jpg',
#  'cat.9828.jpg',
#  'cat.9874.jpg',
#  'cat.9872.jpg',
#  'cat.9879.jpg',
#  'cat.9826.jpg',
#  'cat.986.jpg',
#  'cat.9837.jpg',
#  'cat.9825.jpg',
#  'cat.9838.jpg',
#  'cat.9831.jpg',
#  'cat.9822.jpg',
#  'cat.9848.jpg',
#  'cat.9821.jpg',
#  'cat.9860.jpg',
#  'cat.9839.jpg',
#  'cat.987.jpg',
#  'cat.9859.jpg',
#  'cat.9823.jpg',
#  'cat.9836.jpg',
#  'cat.9845.jpg',
#  'cat.9857.jpg',
#  'cat.9849.jpg',
#  'cat.985.jpg',
#  'cat.9830.jpg',
#  'cat.9824.jpg',
#  'cat.988.jpg',
#  'cat.9887.jpg',
#  'cat.9886.jpg',
#  'cat.9918.jpg',
#  'cat.9885.jpg',
#  'cat.99.jpg',
#  'cat.9934.jpg',
#  'cat.9926.jpg',
#  'cat.9884.jpg',
#  'cat.9892.jpg',
#  'cat.9923.jpg',
#  'cat.9905.jpg',
#  'cat.9893.jpg',
#  'cat.9914.jpg',
#  'cat.989.jpg',
#  'cat.9899.jpg',
#  'cat.9900.jpg',
#  'cat.9909.jpg',
#  'cat.9922.jpg',
#  'cat.9891.jpg',
#  'cat.9894.jpg',
#  'cat.9888.jpg',
#  'cat.9919.jpg',
#  'cat.9911.jpg',
#  'cat.9901.jpg',
#  'cat.991.jpg',
#  'cat.9925.jpg',
#  'cat.9896.jpg',
#  'cat.9898.jpg',
#  'cat.9920.jpg',
#  'cat.9931.jpg',
#  'cat.9929.jpg',
#  'cat.9927.jpg',
#  'cat.9889.jpg',
#  'cat.9915.jpg',
#  'cat.993.jpg',
#  'cat.9895.jpg',
#  'cat.990.jpg',
#  'cat.9928.jpg',
#  'cat.9904.jpg',
#  'cat.9917.jpg',
#  'cat.9913.jpg',
#  'cat.9908.jpg',
#  'cat.9910.jpg',
#  'cat.9903.jpg',
#  'cat.9921.jpg',
#  'cat.9912.jpg',
#  'cat.9897.jpg',
#  'cat.9883.jpg',
#  'cat.9932.jpg',
#  'cat.9890.jpg',
#  'cat.9882.jpg',
#  'cat.9916.jpg',
#  'cat.9933.jpg',
#  'cat.9930.jpg',
#  'cat.9902.jpg',
#  'cat.9906.jpg',
#  'cat.9924.jpg',
#  'cat.992.jpg',
#  'cat.9907.jpg',
#  'cat.9963.jpg',
#  'cat.9949.jpg',
#  'cat.9940.jpg',
#  'cat.9970.jpg',
#  'cat.999.jpg',
#  'cat.9964.jpg',
#  'cat.9991.jpg',
#  'cat.9975.jpg',
#  'cat.9978.jpg',
#  'cat.997.jpg',
#  'cat.998.jpg',
#  'cat.9943.jpg',
#  'cat.9977.jpg',
#  'cat.9976.jpg',
#  'cat.9959.jpg',
#  'cat.9985.jpg',
#  'cat.9936.jpg',
#  'cat.9974.jpg',
#  'cat.9938.jpg',
#  'cat.9984.jpg',
#  'cat.9951.jpg',
#  'cat.9939.jpg',
#  'cat.9954.jpg',
#  'cat.9966.jpg',
#  'cat.9935.jpg',
#  'cat.9979.jpg',
#  'cat.9952.jpg',
#  'cat.9945.jpg',
#  'cat.9947.jpg',
#  'cat.9980.jpg',
#  'cat.9941.jpg',
#  'cat.9960.jpg',
#  'cat.9987.jpg',
#  'cat.9944.jpg',
#  'cat.9942.jpg',
#  'cat.9948.jpg',
#  'cat.995.jpg',
#  'cat.9961.jpg',
#  'cat.9973.jpg',
#  'cat.9946.jpg',
#  'cat.9972.jpg',
#  'cat.9957.jpg',
#  'cat.9983.jpg',
#  'cat.9955.jpg',
#  'cat.994.jpg',
#  'cat.9992.jpg',
#  'cat.9965.jpg',
#  'cat.9950.jpg',
#  'cat.9958.jpg',
#  'cat.9989.jpg',
#  'cat.9981.jpg',
#  'cat.9937.jpg',
#  'cat.9990.jpg',
#  'cat.9982.jpg',
#  'cat.9988.jpg',
#  'cat.996.jpg',
#  'cat.9971.jpg',
#  'cat.9968.jpg',
#  'cat.9986.jpg',
#  'cat.9967.jpg',
#  'cat.9953.jpg',
#  'cat.9969.jpg',
#  'cat.9962.jpg',
#  'cat.9956.jpg',
#  'cat.9996.jpg',
#  'cat.9998.jpg',
#  'cat.9995.jpg',
#  'cat.9999.jpg',
#  'cat.9993.jpg',
#  'cat.9994.jpg',
#  'cat.9997.jpg',
#  ...]

# %%
len(filenames)  # 총 25,000개의 데이터가 있음을 확인
# Out:
# 25000

# %%
df.head()      # filename별로 category가 잘 저장된 것을 확인
# Out:
#        filename  category
# 0  cat.9076.jpg         0
# 1  cat.9114.jpg         0
# 2  cat.9082.jpg         0
# 3   cat.909.jpg         0
# 4  cat.9088.jpg         0

# %%
df.tail()     # filename별로 category가 잘 저장된 것을 확인
# Out:
#             filename  category
# 24995  dog.10853.jpg         1
# 24996  dog.10900.jpg         1
# 24997  dog.10910.jpg         1
# 24998  dog.10903.jpg         1
# 24999  dog.10930.jpg         1

# %% [markdown]
# ## See Total in Count

# %%
# df 데이터프레임에 있는 category col에 있는 value들을 count해서 bar plot 그리기
# 개와 고양이 데이터가 각 몇개인지 확인
df['category'].value_counts().plot.bar(color=['red', 'blue'])

# %%
df['category'].value_counts()
# Out:
# 1    12500
# 0    12500
# Name: category, dtype: int64

# %% [markdown]
# ## See sample image

# %%
# random.choice를 사용하기 위해 위에서 import random을 사용
# 내가 가지고 있던 디렉터리에 있는 list 중에서 아무거나 1개 sampling
sample = random.choice(filenames)

# from keras.preprocessing.image import ImageDataGenerator , load_img를 쓴 이유
image = load_img("/content/gdrive/MyDrive/datasets/.kaggle/train/"+sample)
plt.imshow(image)

# %% [markdown]
# # Build Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Input Layer :** It represent input image data. It will reshape image into single diminsion array.
# Example your image is 64x64 = 4096, it will convert to (4096,1) array.
# - **Conv Layer:** This layer will extract features from image.
# - **Pooling Layer:** This layer reduce the spatial volume of input image after convolution.
# - **Fully Connected Layer:** It connect the network from a layer to another layer
# - **Output Layer:** It is the predicted values layer.

# %%
from keras.models import Sequential  # sequential model은 layer를 선형으로 연결하여 구성한다.
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization  # keras.layers에서 pooling, dropout 등 CNN을 구성하는데 쓰이는 기법

model = Sequential()   # 가장 자주 사용하는 구조인, 층을 순서대로 쌓아 올린 네트워크. keras를 사용하여 모델을 정의(생성)

# Convolution
# 인공신경망 모델을 효율적으로 학습시키기 위한 개선 기법들 ( BatchNormalization, Dropout, ModelEnsemble )

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
'''
1. Conv2D에서 32는 필터의 수, (3,3)은 필터 사이즈
2. 활성화함수는 relu 사용
 *sigmoid가 아닌, relu를 사용하는 이유: 
  신경망이 깊어질수록 학습이 어렵기때문에 전체 계층을 한번 계산한 후 그 계산된 값을 다시 계산하는 역전파(Back Propagation)를 사용하는데,
  sigmoid를 활성화 함수로 사용할 경우, 계층이 깊어지면서 Gradient Vanishing ( 기울기 소실 ) 문제가 발생하기 때문 !!
3. 입력 이미지의 사이즈와 채널
4. 만들어진 모델은 입력 형태에 대한 정보가 필요하기에, Sequential model의 첫번째 layer는 입력 형태에 대한 정보를 받아야 한다.
5. 두 번째 이후의 layer들은 자동으로 형태를 추정할 수 있기때문에 input_shape을 쓸 필요가 없다.
6. input_shape에는 batch dimension은 포함되지 않는다. 
'''

model.add(BatchNormalization())           # 인공신경망에 입력값을 평균 0, 분산 1로 정규화해서 네트워크의 학습이 잘 되도록 함
model.add(MaxPooling2D(pool_size=(2,2)))  # 이미지 사이즈를 줄여주며, 좁은 부분을 자세히 (더 많이) 볼 수 있다.
model.add(Dropout(0.25))                  # 과적합을 방지하기 위해, activation을 0.25의 확률로 지워버림 ( 랜덤으로 노드 삭제 )

model.add(Conv2D(64, (3, 3), activation='relu'))    # 필터의 수 : 64
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation = 'relu'))  # 필터의 수 : 128
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Classifier
model.add(Flatten())    # 이 층에는 학습되는 가중치가 없고, 데이터를 변환하기만 한다 ( 1차원 vector로 변환 ) - 평탄화
model.add(Dense(512, activation='relu'))   # Dense로 층을 쌓음 ( 첫번째 Dense층은 512개의 노드를 가짐 )
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))  # 2: because we have cat and dog classes ( 만약 compile할때 loss에 binary_crossentropy로 설정했다면, 1이 되어야 함 )

# Compile ( 학습 과정 설정 )
model.compile(loss='categorical_crossentropy', # categorical_crossentropy : 손실함수, 가중치 텐서를 학습하기 위한 피드백 신호로 사용되며, 훈련하는 동안 최소화 됨.
                                               # 미니배치 확률적 경사 하강법을 톹ㅇ해 손실이 감소됨   
              
              optimizer='rmsprop',             # optimizer : 데이터와 손실 함수를 바탕으로, 모델의 업데이트 방법을 결정
                                               # rmsprop: 과거의 모든 기울기를 균일하게 더하지 않고, 새로운 기울기의 정보만 반영하도록 해서 학습률이 크게 떨어져 0에 가까워지는 것을 방지하는 방법
              
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau  # 학습 조기 종료를 사용하기 위함

# %% [markdown]
# ### Early Stop
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %% [markdown]
# - 학습 횟수(epoch)가 많을수록 학습 데이터에 관한 오차는 작아지지만, 이것이 `overfitting`을 초래해서 모델의 "일반화" 성능이 떨어짐
# - "이전 epoch 때와 비교해서 '오차가 증가했다면' 학습을 중단한다" 라는 방법인데,
#
#   **주의할점 :** 오차값은 각 epoch마다 올라가기도 하고 내려가기도 하며, Dropout을 적용한 경우에는 아직 학습이 되지 않은 뉴런이 존재할 가능성이 있기때문에 오차값이 상하로 움직이게 된다.
# - 따라서 "어떤 일정한 epoch 수를 거듭하면서 계속해서 오차가 증가하면 학습을 중단한다"라는 방식으로 구현해야 함
# - 아래의 예시를 보면, patience는 오차가 증가하는, 즉, "개선이 없는 epoch 수"가 patience에 지정된 수만큼 지속될 경우 학습을 종료시키기 위해 사용한다.
# - 모델을 학습시키기 전에 다음과 같이 선언한다.
#   - 그 다음 아래에 code를 보면 `model.fit()`이 있는데, `callbacks=early_stopping`을 사용하면 된다.
#   - EarlyStopping은 callback 함수이다.
#   - callback함수: 어떤 함수를 수행할 시, 그 함수에서 내가 지정한 함수를 호출하는 것
#   - `earlystop = EarlyStopping(patience=10)` : 학습 조기종료를 뜻함 ->
#   overfitting을 막기위해서 10 epoch만큼 거슬러 올라가 볼때 "valication loss값이 감소하지 않으면, 학습을 중단하라"라는 의미.

# %%
# 학습 조기종료
earlystop = EarlyStopping(patience=10)

# %%
earlystop

# %% [markdown]
# ### Learn Rate Reduction
# We will reduce the learning rate when then accuracy not increase for 2steps

# %%
# 학습률을 자동으로 감소시키기
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                           patience=2,
                                           verbose=1,
                                           factor=0.5,  # 콜백이 호출될 때, 학습률을 50%로 줄임 (기존 학습룰 * 0.5)
                                           min_lr=0.00001
                                           )

# %% [markdown]
# - monitor : 관찰하고자 하는 항목입니다. ‘val_loss’나 ‘val_acc’가 주로 사용됩니다.
# -> ✨버전 바뀌면서 val_accuracy로 변경됨 !!
# - min_delta : 개선되고 있다고 판단하기 위한 최소 변화량을 나타냅니다. 만약 변화량이 min_delta보다 적은 경우에는 개선이 없다고 판단합니다.
# - patience : 개선이 없다고 바로 종료하지 않고 개선이 없는 에포크를 얼마나 기다려 줄 것인 가를 지정합니다. 만약 10이라고 지정하면 개선이 없는 에포크가 10번째 지속될 경우 학습일 종료합니다.
# - verbose : 얼마나 자세하게 정보를 표시할 것인가를 지정합니다. (0, 1, 2)
# - mode : 관찰 항목에 대해 개선이 없다고 판단하기 위한 기준을 지정합니다. 예를 들어 관찰 항목이 ‘val_loss’인 경우에는 감소되는 것이 멈출 때 종료되어야 하므로, ‘min’으로 설정됩니다.
#   - auto : 관찰하는 이름에 따라 자동으로 지정합니다.
#   - min : 관찰하고 있는 항목이 감소되는 것을 멈출 때 종료합니다.
#   - max : 관찰하고 있는 항목이 증가되는 것을 멈출 때 종료합니다.

# %% [markdown]
# - 모델은 학습이 정체되면 학습 속도를 2~10배 감소시키는 '이점'이 있다.
# - 이때, `ReduceLROnplateau`는 수량을 모니터링하며 patience 수의 epoch수가 '개선되지 않으면'(오차가 증가하면) 학습률이 감소한다.

# %%
callbacks = [earlystop, learning_rate_reduction]  # 학습 조기 종료 , 학습률 자동 감소

# %% [markdown]
# # Prepare data
# Because we will use image genaretor with class_mode="categorical". We need to convert column category into string.
# Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to dog and 0 to cat

# %%
# 0, 1로 OHE 했던 레이블 값을 다시 string으로 변환하기
df["category"] = df["category"].replace({0 : 'cat', 1 : 'dog'})

# %%
df.head()
# Out:
#        filename category
# 0  cat.9076.jpg      cat
# 1  cat.9114.jpg      cat
# 2  cat.9082.jpg      cat
# 3   cat.909.jpg      cat
# 4  cat.9088.jpg      cat

# %%
# train & validation 데이터 분할
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)

# 인덱스 리셋 & drop=True : 인덱스로 셋팅한 열은 데이터 프레임에서 삭제
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df.head()
# Out:
#         filename category
# 0  dog.11159.jpg      dog
# 1  dog.11447.jpg      dog
# 2   cat.8236.jpg      cat
# 3   cat.1014.jpg      cat
# 4   cat.8656.jpg      cat

# %%
train_df['category'].value_counts().plot.bar(color=['red', 'blue'])

# %%
train_df['category'].value_counts()
# Out:
# cat    10014
# dog     9986
# Name: category, dtype: int64

# %%
validate_df['category'].value_counts().plot.bar(color=['red', 'blue'])

# %%
validate_df['category'].value_counts()
# Out:
# dog    2514
# cat    2486
# Name: category, dtype: int64

# %% [markdown]
# dog : train + validate = 12,500
# cat : train + validate = 12,500

# %%
train_df.shape
# Out:
# (20000, 2)

# %%
validate_df.shape
# Out:
# (5000, 2)

# %%
total_train = train_df.shape[0]         # 20,000 개
total_validate = validate_df.shape[0]   #  5,000 개
batch_size = 15

# %% [markdown]
# ## Training Generator

# %%
# 데이터 증식 ( overfitting 방지, 모델 성능 높이기 위함 ) ; Data Agumentation
train_datagen = ImageDataGenerator(
    rotation_range = 15,
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

# %%
# dataframe과 디렉터리의 위치를 전달받아 증식/정규화 된 데이터의 "배치" 생성
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "/content/gdrive/MyDrive/datasets/.kaggle/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size   # batch_size = 15
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# **앞에서 데이터 분할한 것과 같이, train_df는 전체(25,000개)의 80%  :  20,000 개**

# %%
train_datagen

# %%
train_generator

# %% [markdown]
# ## Validation Generator

# %%
# validation 데이터는 증식되면 안됨 !
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "/content/gdrive/MyDrive/datasets/.kaggle/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size    # batch_size = 15
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# **앞에서 데이터 분할한 것과 같이, validation_df는 전체(25,000개)의 20% : 5,000 개**

# %% [markdown]
# ## See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)  # train set인 train_df에서 1개를 sample로 뽑음

# 1개만 가지고 example_generator를 만듦

example_generator = train_datagen.flow_from_dataframe(
    example_df,
    "/content/gdrive/MyDrive/datasets/.kaggle/train",
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical'
)  # sample 1개니까 batch는 안함
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# 샘플 1개니까, 1개의 class에 속해있음

# %%
example_df   # sample로 뭐가 뽑혔는지 확인
# Out:
#        filename category
# 0  cat.4375.jpg      cat

# %%
example_generator

# %%
plt.figure(figsize = (12, 12))  # 그래프의 전체 윈도우 크기

for i in range(0, 15):
  plt.subplot(5, 3, i + 1)      # 5행 3열로 나누고, 위치는 i + 1

  for X_batch, Y_batch in example_generator:
    image = X_batch[0]
    plt.imshow(image)
    break

plt.tight_layout()      # 현재 figure상에서 배치되어 있는 놈들의 공백을 적당하게 잘 배치해주는 것. 여기서는 필수적으로 필요한 것은 아니다.
plt.show()

# %% [markdown]
# **15개의 이미지가 제각각 변형되어 증식된 것을 확인할 수 있다**

# %%
X_batch.shape
# Out:
# (1, 128, 128, 3)

# %%
X_batch
# Out:
# array([[[[0.43300307, 0.3943198 , 0.28904587],
#          [0.7048802 , 0.69226724, 0.6167881 ],
#          [0.65607476, 0.68754816, 0.6778954 ],
#          ...,
#          [0.47536626, 0.36592886, 0.18695848],
#          [0.4024468 , 0.29642317, 0.12996595],
#          [0.40681347, 0.30398336, 0.14502777]],
#
#         [[0.40766445, 0.37795332, 0.2991318 ],
#          [0.4450929 , 0.43294123, 0.35213915],
#          [0.62361336, 0.63498354, 0.5765362 ],
#          ...,
#          [0.36834905, 0.2840761 , 0.20308107],
#          [0.25350982, 0.20473285, 0.13739465],
#          [0.3071081 , 0.2800741 , 0.21300654]],
#
#         [[0.61631227, 0.6068356 , 0.5645171 ],
#          [0.45985803, 0.455704  , 0.39025277],
#          [0.41024128, 0.39637786, 0.32081982],
#          ...,
#          [0.36357653, 0.27013937, 0.15507601],
#          [0.30307746, 0.25761706, 0.17415844],
#          [0.27477762, 0.27893674, 0.23156218]],
#
#         ...,
#
#         [[0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          ...,
#          [0.47445738, 0.4364987 , 0.42030823],
#          [0.42268   , 0.39374456, 0.334921  ],
#          [0.48085865, 0.4699565 , 0.42493376]],
#
#         [[0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          ...,
#          [0.4881141 , 0.44960913, 0.442159  ],
#          [0.41503227, 0.38281918, 0.32399562],
#          [0.46938702, 0.4579386 , 0.40417558]],
#
#         [[0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          [0.43529415, 0.26666668, 0.10196079],
#          ...,
#          [0.5017708 , 0.46271956, 0.46400973],
#          [0.4086622 , 0.37333533, 0.31503597],
#          [0.45952532, 0.44638067, 0.38755715]]]], dtype=float32)

# %%
X_batch[0]
# Out:
# array([[[0.43300307, 0.3943198 , 0.28904587],
#         [0.7048802 , 0.69226724, 0.6167881 ],
#         [0.65607476, 0.68754816, 0.6778954 ],
#         ...,
#         [0.47536626, 0.36592886, 0.18695848],
#         [0.4024468 , 0.29642317, 0.12996595],
#         [0.40681347, 0.30398336, 0.14502777]],
#
#        [[0.40766445, 0.37795332, 0.2991318 ],
#         [0.4450929 , 0.43294123, 0.35213915],
#         [0.62361336, 0.63498354, 0.5765362 ],
#         ...,
#         [0.36834905, 0.2840761 , 0.20308107],
#         [0.25350982, 0.20473285, 0.13739465],
#         [0.3071081 , 0.2800741 , 0.21300654]],
#
#        [[0.61631227, 0.6068356 , 0.5645171 ],
#         [0.45985803, 0.455704  , 0.39025277],
#         [0.41024128, 0.39637786, 0.32081982],
#         ...,
#         [0.36357653, 0.27013937, 0.15507601],
#         [0.30307746, 0.25761706, 0.17415844],
#         [0.27477762, 0.27893674, 0.23156218]],
#
#        ...,
#
#        [[0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         ...,
#         [0.47445738, 0.4364987 , 0.42030823],
#         [0.42268   , 0.39374456, 0.334921  ],
#         [0.48085865, 0.4699565 , 0.42493376]],
#
#        [[0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         ...,
#         [0.4881141 , 0.44960913, 0.442159  ],
#         [0.41503227, 0.38281918, 0.32399562],
#         [0.46938702, 0.4579386 , 0.40417558]],
#
#        [[0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         [0.43529415, 0.26666668, 0.10196079],
#         ...,
#         [0.5017708 , 0.46271956, 0.46400973],
#         [0.4086622 , 0.37333533, 0.31503597],
#         [0.45952532, 0.44638067, 0.38755715]]], dtype=float32)

# %%
X_batch[0, 1]   # 0번째 데이터의 1번째 행
# Out:
# array([[0.40766445, 0.37795332, 0.2991318 ],
#        [0.4450929 , 0.43294123, 0.35213915],
#        [0.62361336, 0.63498354, 0.5765362 ],
#        [0.59177923, 0.5994922 , 0.5459472 ],
#        [0.48250794, 0.46375537, 0.39753994],
#        [0.5698308 , 0.53098536, 0.4620993 ],
#        [0.67367923, 0.6451589 , 0.5938315 ],
#        [0.67905694, 0.6728855 , 0.64874154],
#        [0.6807158 , 0.67263633, 0.66040194],
#        [0.6901961 , 0.67058825, 0.65154934],
#        [0.6901961 , 0.67206734, 0.6411425 ],
#        [0.6876323 , 0.67194605, 0.62752694],
#        [0.68235296, 0.6666667 , 0.6206925 ],
#        [0.68146557, 0.6657793 , 0.62264204],
#        [0.6777412 , 0.66205496, 0.6189177 ],
#        [0.6740169 , 0.6583306 , 0.61519337],
#        [0.67029256, 0.6546063 , 0.61146903],
#        [0.6584848 , 0.6426015 , 0.59932715],
#        [0.3444466 , 0.3211146 , 0.27360973],
#        [0.39921543, 0.3664429 , 0.30070993],
#        [0.41703865, 0.3798451 , 0.30523005],
#        [0.51041996, 0.47971573, 0.41510668],
#        [0.6383349 , 0.6075957 , 0.5612425 ],
#        [0.6613605 , 0.6387392 , 0.6041149 ],
#        [0.6531211 , 0.6365698 , 0.60131943],
#        [0.6512777 , 0.63754296, 0.58896375],
#        [0.64873534, 0.6366701 , 0.5749027 ],
#        [0.6510569 , 0.6291507 , 0.5750474 ],
#        [0.6508445 , 0.6216788 , 0.58074844],
#        [0.6422822 , 0.62211823, 0.57959574],
#        [0.61925375, 0.6127108 , 0.56588304],
#        [0.5529064 , 0.55483186, 0.5078797 ],
#        [0.48882023, 0.4857884 , 0.43101704],
#        [0.55991024, 0.529921  , 0.4663039 ],
#        [0.60722685, 0.57161105, 0.53599524],
#        [0.5737379 , 0.5401933 , 0.5007285 ],
#        [0.4275021 , 0.4033923 , 0.3358557 ],
#        [0.4955454 , 0.48211905, 0.42483553],
#        [0.57270765, 0.55870044, 0.5001409 ],
#        [0.6118675 , 0.5982973 , 0.54420197],
#        [0.616944  , 0.60160035, 0.5546581 ],
#        [0.59340906, 0.5777228 , 0.5390811 ],
#        [0.47314113, 0.44921148, 0.39399716],
#        [0.45633423, 0.42851207, 0.38279775],
#        [0.55206466, 0.53423727, 0.5060337 ],
#        [0.5763648 , 0.5745395 , 0.55069715],
#        [0.56912005, 0.57738143, 0.5504025 ],
#        [0.5674845 , 0.57343405, 0.54307467],
#        [0.5613168 , 0.5594891 , 0.53721035],
#        [0.54301876, 0.5390972 , 0.5261466 ],
#        [0.5123622 , 0.5098738 , 0.4830229 ],
#        [0.4211195 , 0.43045554, 0.37333915],
#        [0.27028546, 0.2892251 , 0.21944535],
#        [0.3423148 , 0.34234297, 0.29862216],
#        [0.5174238 , 0.51182956, 0.48990276],
#        [0.48743957, 0.49059245, 0.47817552],
#        [0.45699573, 0.46613663, 0.45079693],
#        [0.4924769 , 0.48054254, 0.44683588],
#        [0.2552443 , 0.23177771, 0.18592289],
#        [0.43724483, 0.42087498, 0.37739593],
#        [0.36245227, 0.3704438 , 0.34083667],
#        [0.46801975, 0.47978446, 0.45233348],
#        [0.5552276 , 0.57595646, 0.563446  ],
#        [0.71138555, 0.7321241 , 0.7382353 ],
#        [0.6496575 , 0.6588907 , 0.6421254 ],
#        [0.52602196, 0.50837576, 0.4410571 ],
#        [0.38710445, 0.36892703, 0.2831293 ],
#        [0.30159438, 0.30776498, 0.25944537],
#        [0.3219237 , 0.34875047, 0.34930682],
#        [0.5272133 , 0.5641149 , 0.57729274],
#        [0.68797475, 0.7257801 , 0.7240606 ],
#        [0.51725036, 0.53664345, 0.51931065],
#        [0.38748467, 0.37048054, 0.32913503],
#        [0.29616353, 0.28204557, 0.21211065],
#        [0.23487099, 0.21658492, 0.1498047 ],
#        [0.14527193, 0.12195196, 0.09065219],
#        [0.15103881, 0.15219985, 0.17347111],
#        [0.24294524, 0.21208934, 0.18770152],
#        [0.3084154 , 0.23703863, 0.15271953],
#        [0.37291652, 0.27551576, 0.12436385],
#        [0.40446487, 0.29479387, 0.11501186],
#        [0.39437026, 0.2573991 , 0.10269949],
#        [0.33306485, 0.2102281 , 0.03944112],
#        [0.44789243, 0.30797592, 0.08079492],
#        [0.3929364 , 0.28909189, 0.11098184],
#        [0.24129422, 0.18801185, 0.11601546],
#        [0.19432148, 0.16395691, 0.14035848],
#        [0.18907477, 0.16368775, 0.1451687 ],
#        [0.17883213, 0.15764758, 0.14286134],
#        [0.18829042, 0.16906936, 0.1567342 ],
#        [0.19195677, 0.17509481, 0.16088776],
#        [0.19198215, 0.17783721, 0.15703924],
#        [0.17024726, 0.14865363, 0.12313842],
#        [0.17834939, 0.14930709, 0.11713885],
#        [0.18521653, 0.14932397, 0.11343141],
#        [0.19955513, 0.15833782, 0.11751428],
#        [0.24649663, 0.18969826, 0.13187526],
#        [0.2265295 , 0.15494198, 0.0813931 ],
#        [0.24552394, 0.16101147, 0.07635622],
#        [0.2510906 , 0.15811016, 0.06510879],
#        [0.22855172, 0.16657709, 0.07013392],
#        [0.31656212, 0.20427333, 0.06308754],
#        [0.3541858 , 0.24808268, 0.11603292],
#        [0.33819413, 0.3036848 , 0.23525234],
#        [0.31103706, 0.3065573 , 0.26366597],
#        [0.39975405, 0.39610308, 0.33562517],
#        [0.4460444 , 0.44059417, 0.383408  ],
#        [0.4714108 , 0.4710439 , 0.42804393],
#        [0.46163106, 0.46596074, 0.4191035 ],
#        [0.4711204 , 0.4797952 , 0.42206222],
#        [0.50018567, 0.50111026, 0.4495195 ],
#        [0.46201825, 0.42867306, 0.3671086 ],
#        [0.41753697, 0.34273168, 0.22255783],
#        [0.421239  , 0.3486658 , 0.22929311],
#        [0.37329763, 0.3408674 , 0.25156495],
#        [0.3540326 , 0.3575583 , 0.3049128 ],
#        [0.48342398, 0.48412862, 0.44978404],
#        [0.48029208, 0.48882964, 0.46266294],
#        [0.48868182, 0.4970088 , 0.4624335 ],
#        [0.49529988, 0.50523704, 0.4486143 ],
#        [0.49922827, 0.5075061 , 0.47124782],
#        [0.5109145 , 0.50927085, 0.45012543],
#        [0.5020563 , 0.49854416, 0.4270997 ],
#        [0.4068448 , 0.34849262, 0.21873765],
#        [0.42734227, 0.3338507 , 0.21989088],
#        [0.36834905, 0.2840761 , 0.20308107],
#        [0.25350982, 0.20473285, 0.13739465],
#        [0.3071081 , 0.2800741 , 0.21300654]], dtype=float32)

# %%
X_batch[0, 1, 0]
# Out:
# array([0.40766445, 0.37795332, 0.2991318 ], dtype=float32)

# %%
Y_batch.shape
# Out:
# (1, 1)

# %%
Y_batch
# Out:
# array([[1.]], dtype=float32)

# %%
Y_batch[0]
# Out:
# array([1.], dtype=float32)

# %%
Y_batch[0, 0]
# Out:
# 1.0

# %%
print(Y_batch)
# Out:
# [[1.]]

# %% [markdown]
# # Fit Model

# %% [markdown]
# #### **학습 조기종료 조건**
# `earlystop = EarlyStopping(patience=10)`
# 10 epoch만큼 거슬러 올라가 볼때 `valication loss`가 감소하지 않으면, 학습 중단
#
#
# #### **학습률 자동감소 조건**
# `learning_rate_reduction = ReduceLROnPlateau
# (monitor='val_accuracy',
#                                            patience=2,
#                                            verbose=1,
#                                            factor=0.5,
#                                            min_lr=0.00001
#                                            )`
#
# `val_accuracy`가 2번 연속 높아지지 않으면(감소하면), 바로 학습률 감소 !

# %%
epochs = 3 if FAST_RUN else 50

history = model.fit(
    train_generator,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,   # 1,333.33 => total_validate = 20,000개, batch_size = 15
    steps_per_epoch = total_train//batch_size,       # 333.33 => total_train = 5,000개, batch_size = 15
    callbacks = callbacks
)
# Out:
# Epoch 1/50
# 1333/1333 [==============================] - 159s 116ms/step - loss: 0.9056 - accuracy: 0.6053 - val_loss: 0.5657 - val_accuracy: 0.7233
# Epoch 2/50
# 1333/1333 [==============================] - 151s 114ms/step - loss: 0.5686 - accuracy: 0.7131 - val_loss: 0.5240 - val_accuracy: 0.7479
# Epoch 3/50
# 1333/1333 [==============================] - 150s 113ms/step - loss: 0.5141 - accuracy: 0.7531 - val_loss: 0.6013 - val_accuracy: 0.7185
# Epoch 4/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.4755 - accuracy: 0.7758 - val_loss: 0.7676 - val_accuracy: 0.7417
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.4198 - accuracy: 0.8129 - val_loss: 0.3690 - val_accuracy: 0.8358
# Epoch 6/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.4015 - accuracy: 0.8184 - val_loss: 0.4290 - val_accuracy: 0.8202
# Epoch 7/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.3909 - accuracy: 0.8265 - val_loss: 0.3212 - val_accuracy: 0.8643
# Epoch 8/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3675 - accuracy: 0.8355 - val_loss: 0.2965 - val_accuracy: 0.8841
# Epoch 9/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3526 - accuracy: 0.8468 - val_loss: 0.3258 - val_accuracy: 0.8627
# Epoch 10/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3490 - accuracy: 0.8480 - val_loss: 0.4397 - val_accuracy: 0.8326
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3402 - accuracy: 0.8498 - val_loss: 0.2723 - val_accuracy: 0.8841
# Epoch 12/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3235 - accuracy: 0.8563 - val_loss: 0.2487 - val_accuracy: 0.8977
# Epoch 13/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3185 - accuracy: 0.8633 - val_loss: 0.2388 - val_accuracy: 0.8987
# Epoch 14/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.3141 - accuracy: 0.8659 - val_loss: 0.2626 - val_accuracy: 0.8935
# Epoch 15/50
# 1333/1333 [==============================] - 152s 114ms/step - loss: 0.3160 - accuracy: 0.8617 - val_loss: 0.2448 - val_accuracy: 0.9015
# Epoch 16/50
# 1333/1333 [==============================] - 151s 113ms/step - loss: 0.3138 - accuracy: 0.8650 - val_loss: 0.2418 - val_accuracy: 0.9019
# Epoch 17/50
# 1333/1333 [==============================] - 152s 114ms/step - loss: 0.2979 - accuracy: 0.8718 - val_loss: 0.2637 - val_accuracy: 0.8877
# Epoch 18/50
# 1333/1333 [==============================] - 151s 113ms/step - loss: 0.3009 - accuracy: 0.8735 - val_loss: 0.2282 - val_accuracy: 0.9081
# Epoch 19/50
# 1333/1333 [==============================] - 150s 113ms/step - loss: 0.3105 - accuracy: 0.8689 - val_loss: 0.2332 - val_accuracy: 0.9075
# Epoch 20/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.2903 - accuracy: 0.8779 - val_loss: 0.2260 - val_accuracy: 0.9079
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 21/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.2786 - accuracy: 0.8839 - val_loss: 0.2159 - val_accuracy: 0.9097
# Epoch 22/50
# 1333/1333 [==============================] - 150s 113ms/step - loss: 0.2885 - accuracy: 0.8802 - val_loss: 0.2369 - val_accuracy: 0.9061
# Epoch 23/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2681 - accuracy: 0.8853 - val_loss: 0.2353 - val_accuracy: 0.9059
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 24/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.2808 - accuracy: 0.8800 - val_loss: 0.2118 - val_accuracy: 0.9157
# Epoch 25/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2687 - accuracy: 0.8905 - val_loss: 0.2187 - val_accuracy: 0.9099
# Epoch 26/50
# 1333/1333 [==============================] - 150s 112ms/step - loss: 0.2645 - accuracy: 0.8920 - val_loss: 0.2044 - val_accuracy: 0.9171
# Epoch 27/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2653 - accuracy: 0.8891 - val_loss: 0.2185 - val_accuracy: 0.9093
# Epoch 28/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2694 - accuracy: 0.8870 - val_loss: 0.2184 - val_accuracy: 0.9127
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 29/50
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2750 - accuracy: 0.8846 - val_loss: 0.2098 - val_accuracy: 0.9149
# Epoch 30/50
# 1333/1333 [==============================] - 151s 113ms/step - loss: 0.2631 - accuracy: 0.8919 - val_loss: 0.2156 - val_accuracy: 0.9119
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 31/50
# 1333/1333 [==============================] - 151s 113ms/step - loss: 0.2757 - accuracy: 0.8851 - val_loss: 0.2163 - val_accuracy: 0.9119
# Epoch 32/50
# 1333/1333 [==============================] - 152s 114ms/step - loss: 0.2725 - accuracy: 0.8890 - val_loss: 0.2104 - val_accuracy: 0.9139
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 33/50
# 1333/1333 [==============================] - 152s 114ms/step - loss: 0.2675 - accuracy: 0.8899 - val_loss: 0.2108 - val_accuracy: 0.9149
# Epoch 34/50
# 1333/1333 [==============================] - 152s 114ms/step - loss: 0.2626 - accuracy: 0.8916 - val_loss: 0.2089 - val_accuracy: 0.9153
# Epoch 35/50
# 1333/1333 [==============================] - 151s 114ms/step - loss: 0.2558 - accuracy: 0.8922 - val_loss: 0.2095 - val_accuracy: 0.9151
# Epoch 36/50
# 1333/1333 [==============================] - 151s 114ms/step - loss: 0.2606 - accuracy: 0.8935 - val_loss: 0.2067 - val_accuracy: 0.9161

# %% [markdown]
# # Save Model

# %%
model.save_weights("model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-71af9f14cda8> in <module>()
# ----> 1 model.save_weights("model.h5")
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize= (12, 12))

ax1.plot(history.history['loss'], color='b', label='Training loss')
ax1.plot(history.history['val_loss'], color='r', label='Validation loss')
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label='Training accuracy')   # 'acc' -> 'accuracy'
ax2.plot(history.history['val_accuracy'], color='r', label='Validation accuracy')
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-08f0b3749a7d> in <module>()
# ----> 1 fig, (ax1, ax2) = plt.subplots(2, 1, figsize= (12, 12))
#       2
#       3 ax1.plot(history.history['loss'], color='b', label='Training loss')
#       4 ax1.plot(history.history['val_loss'], color='r', label='Validation loss')
#       5 ax1.set_xticks(np.arange(1, epochs, 1))
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir('/content/gdrive/MyDrive/datasets/.kaggle/test1')
test_df = pd.DataFrame({
    'filename' : test_filenames
})
nb_samples = test_df.shape[0]  # test dataset 개수

# %%
test_df.shape
# Out:
# (12500, 1)

# %% [markdown]
# # Create Testing Generator

# %%
# test 데이터는 증식되면 안됨 ! 
test_gen = ImageDataGenerator(rescale = 1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df,
    "/content/gdrive/MyDrive/datasets/.kaggle/test1",
    x_col = 'filename',
    y_col = None,
    class_mode = None,
    target_size = IMAGE_SIZE,
    batch_size = batch_size,  # batch_size = 15
    shuffle = False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# # Predict

# %%
predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size)) # model.predict_generator -> model.predict
# -np.ceil(data) : 소수점 자리 수를 '올림'해서 정수로 만들어줌
# nb_samples : test dataset의 갯수
# batch_size = 15

# %%
predict

# %%
test_df

# %%
np.argmax(predict, axis=-1)

# %% [markdown]
# For categoral classication the prediction will come with probability of each category.
# So we will pick the category that have the highest probability with numpy average max.

# %%
# axis = -1 에서 가장 큰 값의 인덱스를 반환 ( 여기에서는 0과 1 중 큰 값인 1을 가진 인덱스를 반환함)
# 1 = dog
test_df['category'] = np.argmax( predict, axis= -1 )

# %%
test_df['category']

# %% [markdown]
# We will convert the predict category back into our generator classes by using `train_generator.class_indices.`
# It is the classes that image generator map while converting data into computer vision.

# %%
test_df

# %%
label_map = dict((v, k) for k, v in train_generator.class_indices.items())

# category를 1, 0 ->  dog, cat으로 변환
test_df['category'] = test_df['category'].replace(label_map)

# %% [markdown]
# From our prepare data part. We map data with `{1: 'dog', 0: 'cat'}`.
# Now we will map the result back to dog is 1 and cat is 0

# %%
test_df

# %%
# category를 dog, cat -> 1, 0 으로 변환
test_df['category'] = test_df['category'].replace({ 'dog' : 1 , 'cat' : 0 })

# %%
test_df

# %% [markdown]
# #### Virtualize Result

# %%
test_df['category'].value_counts().plot.bar()

# %%
test_df['category'].value.counts()

# %% [markdown]
# #### See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()

# %%
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
  filename = row['filename']   # filename = 칼럼명 filename의 값들이 1개의 행으로 나열된 형태
  category = row['category']   # category = 칼럼명 category의 값들이 1개의 행으로 나열된 형태
  img = load_img("/content/gdrive/MyDrive/datasets/.kaggle/test1"+filename, target_size=IMAGE_SIZE)
  plt.subplot(6, 3, index+1)
  plt.imshow(img)
  plt.xlabel(filename + '(' + "{}".format(category) + ')' )

plt.tight_layout()  # 자동으로 레이아웃을 맞춰주는 함수 (여백을 알아서 맞춰줌)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Submission

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)
